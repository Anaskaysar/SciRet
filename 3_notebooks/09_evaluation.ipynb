# %% [markdown]
# # 09 Evaluation
#
# Purpose: report retrieval and grounded-generation metrics for paper tables.
#
# Inputs: retrieval outputs from 04/05/08 and evaluation labels.
# Outputs: `4_results/comparison_table.md`, evaluation CSV/plots.

# %%
from pathlib import Path

ROOT = Path('..').resolve()
out_dir = ROOT / '4_results'
out_dir.mkdir(parents=True, exist_ok=True)
table_path = out_dir / 'comparison_table.md'

table = '''| System | Recall@5 | MRR | NDCG@10 | Faithfulness | Relevance | Citation Integrity |
|---|---:|---:|---:|---:|---:|---:|
| SciRet v1 | - | - | - | - | - | - |
| SciRet v2 text-only | - | - | - | - | - | - |
| SciRet v2 multimodal | - | - | - | - | - | - |
'''
table_path.write_text(table)
print(f'Initialized result table -> {table_path}')
