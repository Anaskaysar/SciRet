# %% [markdown]
# # 05 Reranking
#
# Purpose: apply a cross-encoder reranker on top retrieval candidates.
#
# Input: candidate lists from notebook 04.
# Output: reranked candidates and before/after metric snapshots.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path('..').resolve()
in_dir = ROOT / '4_results' / 'retrieval'
out_dir = ROOT / '4_results' / 'retrieval'
out_dir.mkdir(parents=True, exist_ok=True)

print('TODO: load top-N candidates, run cross-encoder reranker, save reranked outputs')
print(f'Input folder exists: {in_dir.exists()}')
